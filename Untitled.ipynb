# %%
def six7(nm) :

    for i in range (nm):
        print("Six Sevennnnnn🗣️🗣️🗣️")
        print("Six Sevennnnnn🗣️🗣️🗣️")

    print("You get double yayyyy 🔥🔥🔥🔥👻👻👻👻👻👻")

n = int(input("How many 67 ?👀 "))
        
six7(n)
# Out:
# How many 67 ?👀  14
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# Six Sevennnnnn🗣️🗣️🗣️
# You get double yayyyy 🔥🔥🔥🔥👻👻👻👻👻👻
