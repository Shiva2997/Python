# %%
# Store 5 string values from user and store them as part tuple .


values = []

for i in range(5):
    s = input(f"Enter string {i+1}: ")
    values.append(s)

result = tuple(values)

print("Tuple:", result)
# Out:
# Enter string 1:  ieuhdi
# Enter string 2:  ljhewbc
# Enter string 3:  lwehc
# Enter string 4:  ehdc
# Enter string 5:  eflc
# Tuple: ('ieuhdi', 'ljhewbc', 'lwehc', 'ehdc', 'eflc')

# %%
s = {10, 20, 30, 40 , 5}
print(s)
# Out:
# {20, 5, 40, 10, 30}

# %%
A = { 1 ,2, 3, 4}
B = {3, 4, 5, 6}
print(A|B)
print(A&B)
print(A-B)
print(A-B)
print(A^B)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2}
# {1, 2, 5, 6}

# %%
# 1. Remove duplicates .


# 4. Employee tuple.


numbers = [10, 20, 30, 20, 40, 10, 50, 30]

unique = set(numbers)

print("Original List:", numbers)
print("Unique Elements:", unique)
# Out:
# Original List: [10, 20, 30, 20, 40, 10, 50, 30]
# Unique Elements: {40, 10, 50, 20, 30}

# %%
# 2. Find common subjects
student1 = {"Math", "Physics", "English", "Python"}
student2 = {"Python", "Math", "Chemistry", "Biology"}

common = student1.intersection(student2)

print("Common Subjects:", common)
# Out:
# Common Subjects: {'Python', 'Math'}

# %%
# 3. Compare tuples and sets 
t = (10, 20, 30, 20)
s = {10, 20, 30, 20}

print("Tuple:", t)
print("Set:", s)

print("\nLength of Tuple:", len(t))
print("Length of Set:", len(s))

# %%
# 4. Employee tuple.
employee = ("E101", "Rahul", "Developer", 65000)

print("Employee ID:", employee[0])
print("Employee Name:", employee[1])
print("Designation:", employee[2])
print("Salary:", employee[3])

# %%
# 5. Unique cities
cities = ["Delhi", "Mumbai", "Delhi", "Jaipur", "Pune", "Mumbai", "Chennai"]

unique_cities = set(cities)

print("Unique Cities:", unique_cities)

# %%
student = {
    "Name" : "Rahul" ,
    "Age" : 22 ,
    "CGPA" : 8.4 
}
print(student)
print(student.get("Name"))
print(student.get("Phone"))
print(student["Name"])

student.popitem()
print(student)
# Out:
# {'Name': 'Rahul', 'Age': 22, 'CGPA': 8.4}
# Rahul
# None
# Rahul
# {'Name': 'Rahul', 'Age': 22}

# %%
# Dictionary comprehension equivalent
squares = {x: x ** 2 for x in range(1, 6)}
print(squares)

# %%
student = {"Name" : "Shiva" , 
           "Age" : 21 ,
           "CGPA" : 6.9 ,
           "Departmment" : "CSE" }
student["Number"] = 8755223687
print(student)

student.pop("CGPA")
print(student)

for key in student:
    print(key)

for value in student:
    print(value)

for key, value in student.items():
    print(key, ":", value)
# Out:
# {'Name': 'Shiva', 'Age': 21, 'CGPA': 6.9, 'Departmment': 'CSE', 'Number': 8755223687}
# {'Name': 'Shiva', 'Age': 21, 'Departmment': 'CSE', 'Number': 8755223687}
# Name
# Age
# Departmment
# Number
# Name
# Age
# Departmment
# Number
# Name : Shiva
# Age : 21
# Departmment : CSE
# Number : 8755223687
# {'Student1': {'Name': 'Shiva', 'Age': 21, 'Branch': 'CSE'}, 'Student2': {'Name': 'Rahul', 'Age': 22, 'Branch': 'IT'}}
# Shiva

# %%
students = {
    "Student1": {
        "Name": "Shiva",
        "Age": 21,
        "Branch": "CSE"
    },
    "Student2": {
        "Name": "Rahul",
        "Age": 22,
        "Branch": "IT"
    }
}

print(students)

print(students["Student1"]["Name"])

# %%
# Dictionary Comprehension for Cubes
cubes = {x: x**3 for x in range(1, 6)}

print(cubes)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %%
# Counting the frequency of characters
text = input("Enter a string: ")

freq = {}

for ch in text:
    if ch in freq:
        freq[ch] += 1
    else:
        freq[ch] = 1

print(freq)
# Out:
# Enter a string:  ewdbwhbcjwdbchb  iuwehciwh iwh c
# {'e': 2, 'w': 6, 'd': 2, 'b': 4, 'h': 5, 'c': 4, 'j': 1, ' ': 4, 'i': 3, 'u': 1}

# %%
temp = []
for i in range(15):
    a = int(input("Give temperature"))
    temp.append(a)
print(temp)
print(max(temp))
print(min(temp))
average = sum(my_list) / len(my_list)
print(average)
# Out:
# Give temperature 76
# Give temperature 4r
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 temp = []
#       2 for i in range(15):
# ----> 3     a = int(input("Give temperature"))
#       4     temp.append(a)
#       5 print(temp)
#
# ValueError: invalid literal for int() with base 10: '4r '

# %%
# Store the nuoque programming langauges known by a class and display them alphabetically
words = set()

for i in range(5):
    s = input("Enter a string: ")
    words.add(s)

print("Unique Strings:", words)

print("\nAlphabetical Order:")
for word in sorted(words):
    print(word)
# Out:
# Enter a string:  6788
# Enter a string:  67
# Enter a string:  fd
# Enter a string:  gjiol
# Enter a string:  jhbjhb
# Unique Strings: {'gjiol', 'fd', '67', 'jhbjhb', '6788'}
#
# Alphabetical Order:
# 67
# 6788
# fd
# gjiol
# jhbjhb

# %%
# Store coordinates of 8 chess pieces such that coordinates cannot be modified accidently

# %%
a = ["Veere" , "Haddi" , "Shoot out" , "Dhinka Chika"]
b = ["Dhinka Chika"]
print(ab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 a = ["Veere" , "Haddi" , "Shoot out" , "Dhinka Chika"]
#       2 b = ["Dhinka Chika"]
# ----> 3 print(a^b)
#
# TypeError: unsupported operand type(s) for ^: 'list' and 'list'
