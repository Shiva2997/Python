# %%
# Hospital code 

for i in range(1 , 4):
    for j in range(1 , 5):
        for k in range(101 , 111):
            print("Buiding no. " , i , "Floor " , j , 'Room no. ' , k )
        
    print()
print()
# Out:
# Buiding no.  1 Floor  1 Room no.  101
# Buiding no.  1 Floor  1 Room no.  102
# Buiding no.  1 Floor  1 Room no.  103
# Buiding no.  1 Floor  1 Room no.  104
# Buiding no.  1 Floor  1 Room no.  105
# Buiding no.  1 Floor  1 Room no.  106
# Buiding no.  1 Floor  1 Room no.  107
# Buiding no.  1 Floor  1 Room no.  108
# Buiding no.  1 Floor  1 Room no.  109
# Buiding no.  1 Floor  1 Room no.  110
# Buiding no.  1 Floor  2 Room no.  101
# Buiding no.  1 Floor  2 Room no.  102
# Buiding no.  1 Floor  2 Room no.  103
# Buiding no.  1 Floor  2 Room no.  104
# Buiding no.  1 Floor  2 Room no.  105
# Buiding no.  1 Floor  2 Room no.  106
# Buiding no.  1 Floor  2 Room no.  107
# Buiding no.  1 Floor  2 Room no.  108
# Buiding no.  1 Floor  2 Room no.  109
# Buiding no.  1 Floor  2 Room no.  110
# Buiding no.  1 Floor  3 Room no.  101
# Buiding no.  1 Floor  3 Room no.  102
# Buiding no.  1 Floor  3 Room no.  103
# Buiding no.  1 Floor  3 Room no.  104
# Buiding no.  1 Floor  3 Room no.  105
# ...

# %% [raw]
# Q1 Three level nested loop is code snippet where there are loops one in another at three levels . Creating somewhat of a 3-D matrix . As the no. of nested loops we increase one more dimension is added to our imaginary metrix .

# %% [raw]
# Q2 One loop inside another loop , inside another loop

# %% [raw]
# Q3 The last loop inside the nested loops works first and then the loops above it starts working , one after another.

# %% [raw]
# Q4 Outer loop

# %% [raw]
# Q5 False

# %% [raw]
# Q6 False

# %%
Q7 Country State City
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Q7
#
# NameError: name 'Q7' is not defined

# %% [raw]
# Q8 Three

# %% [raw]
# Q9 n to the power of five where n is the no. of loops

# %% [raw]
# Q10  1) Hospital - rooms - Beds
#      2) Country - State - city

# %% [raw]
# Q11 There would be six outcomes.
#
# 000
# 001
# 010
# 011
# 111

# %% [raw]
# Q 12 There would be six outcomes
#
# 000
# 001
