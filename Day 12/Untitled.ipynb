# %%
l1 = ["Mouse"]
l1.append("Monitor")
print(l1)
l1.remove("Mouse")
print(l1)
# Out:
# ['Mouse', 'Monitor']
# ['Monitor']

# %%
l1 = ["A1" , "A2" , "A3" , "A4"]
l1.insert(1 , "A3")
print(l1)
# Out:
# ['A1', 'A3', 'A2', 'A3', 'A4']

# %%
l1 = [213 , 23234 , 24243 , 4242 , 422]
l1.pop()
print(l1)
# Out:
# [213, 23234, 24243, 4242]

# %%
l1 = ["iuhfsdv" , "eoijiew" , "fwjke" , "rfefin" ]
l1.sort()
print(l1)
l1.reverse()
print(l1)
# Out:
# ['eoijiew', 'fwjke', 'iuhfsdv', 'rfefin']
# ['rfefin', 'iuhfsdv', 'fwjke', 'eoijiew']

# %%
students = ["Aman", "Rahul", "Priya", "Rahul", "Aman", "Rahul", "Riya"]

print("Aman's Position:", students.index("Aman"))
print("Rahul Occurrences:", students.count("Rahul"))

# %%
playlist1 = ["Shape of You", "Believer", "Perfect"]
playlist2 = ["Blinding Lights", "Levitating", "Senorita"]
print(playlist1)
playlist1.extend(playlist2)
                                        
print("Merged Playlist:")
print(playlist1)
# Out:
# ['Shape of You', 'Believer', 'Perfect']
# Merged Playlist:
# ['Shape of You', 'Believer', 'Perfect', 'Blinding Lights', 'Levitating', 'Senorita']

# %%
#Library management system: Store books , add books , search issue , return , create backup
# display final library using appropriate list methods

Library_Data = ["lord of the rings" , "Verity" , "The jungle book"  , "The DaVinci Code" , "Finding Poornima"]
n = int(input("how many books you want to add "))
book = input("Which Book you waant ")

if book in Library_Data:
    print("Yes the book is available" , Library_Data.index(book))
else :
    print("book is not available")
    
while n > 0 :
    a = input("Add book")
    Library_Data.append(a)
    n -= 1 

book = input("Which Book you waant ")

if book in Library_Data:
    print("Yes the book is available" , Library_Data.index(book))
else :
    print("book is not available")
    

Library_Data2 = Library_Data.copy()

for i in Library_Data:
    print(i)
# Out:
# how many books you want to add  1
# Which Book you waant  gandhi
# book is not available
